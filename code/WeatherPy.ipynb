# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

from pprint import pprint

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={api_key}&q="

cit = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lon = []
max_temp = []
wind_speed = []

print("Begining data retrieval")
print("-----------------------")

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        time.sleep(1)
        cit.append(response['name'])
        print(f"Processing {len(cit)} of {len(cities)} : {city}")
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
    except:
        print("Error, skipping")
print(f"Processed{len(cit)}")
# Out:
# Begining data retrieval
# -----------------------
# Processing : kodiak
# Processing : tiarei
# Processing : tuktoyaktuk
# Processing : albany
# Processing : cururupu
# Processing : vaitupu
# Error, skipping
# Processing : tasiilaq
# Processing : havelock
# Processing : fortuna
# Processing : cape town
# Processing : avarua
# Processing : hengshui
# Processing : qaanaaq
# Processing : narsaq
# Processing : busselton
# Processing : sosnovoborsk
# Processing : mataura
# Processing : nemuro
# Processing : hermanus
# Processing : port hedland
# Processing : belushya guba
# Error, skipping
# Processing : tynda
# Processing : ushuaia
# Processing : rocky mountain house
# Processing : shache
# Processing : awjilah
# Processing : vaini
# Processing : kavaratti
# Processing : trincomalee
# Processing : butaritari
# Processing : lavrentiya
# Processing : chokurdakh
# Processing : sao filipe
# Processing : leirvik
# Processing : gizo
# Processing : clyde river
# Processing : taolanaro
# Error, skipping
# Processing : burica
# Error, skipping
# Processing : caravelas
# Processing : port elizabeth
# Processing : hithadhoo
# Processing : itarema
# Processing : lagoa
# Processing : hobart
# Processing : castro
# Processing : caririacu
# Processing : ankola
# Processing : thompson
# Processing : pontianak
# Processing : bathsheba
# Processing : hualmay
# Processing : sao joao da barra
# Processing : bara
# Processing : victoria
# Processing : humaita
# Processing : bandarbeyla
# Processing : pune
# Processing : achisay
# Error, skipping
# Processing : hofn
# Processing : clonakilty
# Processing : barentsburg
# Error, skipping
# Processing : wad rawah
# Processing : hilo
# Processing : severo-kurilsk
# Processing : torbay
# Processing : atuona
# Processing : roald
# Processing : harda
# Processing : mangrol
# Processing : nouadhibou
# Processing : rikitea
# Processing : tongliao
# Processing : shihezi
# Processing : bambous virieux
# Processing : atlantic city
# Error, skipping
# Processing : kuching
# Processing : mahebourg
# Processing : gilbues
# Processing : port alfred
# Processing : punta arenas
# Processing : neuquen
# Processing : luwuk
# Processing : mandera
# Processing : bethel
# Processing : khatanga
# Processing : kharan
# Processing : wladyslawowo
# Processing : miyang
# Processing : yatou
# Processing : upernavik
# Processing : kloulklubed
# Processing : san juan
# Processing : jamestown
# Processing : mingaora
# Processing : airai
# Processing : kuche
# Error, skipping
# Processing : tsybuliv
# Processing : bluff
# Processing : georgetown
# Processing : lorengau
# Processing : phan thiet
# Processing : namtsy
# Processing : ilulissat
# Processing : saskylakh
# Processing : skalistyy
# Error, skipping
# Processing : sioux lookout
# Processing : te anau
# Processing : kapoeta
# Error, skipping
# Processing : umzimvubu
# Error, skipping
# Processing : dikson
# Processing : palabuhanratu
# Error, skipping
# Processing : forbes
# Processing : imperia
# Processing : esperance
# Processing : mackay
# Processing : igarka
# Processing : raga
# Error, skipping
# Processing : vao
# Processing : handan
# Processing : kaitangata
# Processing : griffith
# Processing : mwinilunga
# Processing : leeton
# Processing : ust-tsilma
# Processing : solsvik
# Error, skipping
# Processing : orange cove
# Processing : batagay-alyta
# Processing : hami
# Processing : mpika
# Processing : concepcion del oro
# Processing : new norfolk
# Processing : grand river south east
# Error, skipping
# Processing : mombetsu
# Processing : east london
# Processing : kichmengskiy gorodok
# Processing : carnarvon
# Processing : yellowknife
# Processing : pevek
# Processing : falealupo
# Error, skipping
# Processing : arraial do cabo
# Processing : shujaabad
# Processing : yongan
# Processing : reftinskiy
# Processing : podosinovets
# Processing : barranca
# Processing : san cristobal
# Processing : mogochin
# Error, skipping
# Processing : poum
# Processing : sobreira
# Processing : vyartsilya
# Processing : port lincoln
# Processing : homer
# Processing : yulara
# Processing : mathathane
# Processing : san patricio
# Processing : jacareacanga
# Processing : hasaki
# Processing : romitan
# Processing : saldanha
# Processing : isangel
# Processing : saint george
# Processing : terrace
# Processing : youghal
# Processing : flores
# Processing : kahului
# Processing : norman wells
# Processing : tuatapere
# Processing : khani
# Processing : cortland
# Processing : ancud
# Processing : inirida
# Processing : priargunsk
# Processing : bredasdorp
# Processing : petropavlovsk-kamchatskiy
# Processing : illoqqortoormiut
# Error, skipping
# Processing : longyearbyen
# Processing : labuhan
# Processing : mahibadhoo
# Processing : cidreira
# Processing : yar-sale
# Processing : nikolskoye
# Processing : ust-maya
# Processing : kapaa
# Processing : kathu
# Processing : alice springs
# Processing : mitrofanovka
# Processing : yunjinghong
# Error, skipping
# Processing : zhanaozen
# Processing : beringovskiy
# Processing : bengkulu
# Error, skipping
# Processing : pangnirtung
# Processing : mar del plata
# Processing : nizhneyansk
# Error, skipping
# Processing : palu
# Processing : mareeba
# Processing : pangkalanbuun
# Processing : vila franca do campo
# Processing : komsomolskiy
# Processing : portland
# Processing : inuvik
# Processing : antofagasta
# Processing : codrington
# Processing : wyszkow
# Processing : kavieng
# Processing : payo
# Processing : tommot
# Processing : egvekinot
# Processing : bilibino
# Processing : fairbanks
# Processing : cuxhaven
# Processing : chicama
# Processing : north bend
# Processing : ribeira grande
# Processing : mount isa
# Processing : santa maria
# Processing : dubbo
# Processing : minsk
# Processing : mehamn
# Processing : praia
# Processing : novobirilyussy
# Processing : banyuwangi
# Processing : manado
# Processing : hovd
# Processing : nacala
# Processing : calvinia
# Processing : omsukchan
# Processing : talnakh
# Processing : guarda
# Processing : ponta do sol
# Processing : dingle
# Processing : cabo san lucas
# Processing : puerto ayora
# Processing : korla
# Error, skipping
# Processing : asau
# Error, skipping
# Processing : souillac
# Processing : mys shmidta
# Error, skipping
# Processing : pangai
# Processing : inderborskiy
# Error, skipping
# Processing : vila velha
# Processing : along
# Processing : tambacounda
# Processing : nome
# Processing : ostrovnoy
# Processing : mrirt
# Error, skipping
# Processing : wajir
# Processing : qasigiannguit
# Processing : saint-pierre
# Processing : kununurra
# Processing : novikovo
# Processing : el carmen
# Processing : ahipara
# Processing : shaartuz
# Error, skipping
# Processing : boa vista
# Processing : saint-philippe
# Processing : osa
# Processing : usinsk
# Processing : lixourion
# Processing : griffin
# Processing : zyryanka
# Processing : sentyabrskiy
# Error, skipping
# Processing : cayenne
# Processing : faanui
# Processing : olafsvik
# Error, skipping
# Processing : nanortalik
# Processing : seinajoki
# Error, skipping
# Processing : kouroussa
# Processing : ulladulla
# Processing : evensk
# Processing : kurilsk
# Processing : paamiut
# Processing : maceio
# Processing : guerrero negro
# Processing : tshane
# Processing : jasidih
# Processing : amderma
# Error, skipping
# Processing : barrow
# Processing : cuencame
# Processing : galbshtadt
# Processing : alotau
# Error, skipping
# Processing : san mateo ixtatan
# Processing : tarko-sale
# Processing : cherskiy
# Processing : saint-cyr-sur-loire
# Processing : denpasar
# Processing : taseyevo
# Processing : provideniya
# Processing : jarvenpaa
# Processing : kruisfontein
# Processing : kropotkin
# Processing : hambantota
# Processing : gigmoto
# Processing : igarape-acu
# Error, skipping
# Processing : constitucion
# Processing : primorsk
# Processing : high level
# Processing : saint-augustin
# Processing : meyungs
# Error, skipping
# Processing : gat
# Processing : minot
# Processing : chuy
# Processing : peniche
# Processing : yanam
# Processing : lata
# Processing : catuday
# Processing : kopavogur
# Processing : cabedelo
# Processing : sitka
# Processing : acari
# Processing : bontang
# Processing : dinsor
# Error, skipping
# Processing : srednebelaya
# Processing : waingapu
# Processing : toamasina
# Processing : cuamba
# Processing : teahupoo
# Processing : mayo
# Processing : dalvik
# Processing : naze
# Processing : burnie
# Processing : pacific grove
# Processing : inhambane
# Processing : ketchikan
# Processing : namibe
# Processing : salalah
# Processing : llangefni
# Processing : yerbogachen
# Processing : norfolk
# Processing : hargeysa
# Processing : coquimbo
# Processing : jasper
# Processing : grand-lahou
# Processing : bambanglipuro
# Processing : ermoupolis
# Processing : maarianhamina
# Error, skipping
# Processing : ilhabela
# Processing : khovu-aksy
# Processing : alanya
# Processing : haines junction
# Processing : port macquarie
# Processing : labutta
# Error, skipping
# Processing : acheng
# Processing : ozinki
# Processing : xambioa
# Error, skipping
# Processing : ikongo
# Processing : karaul
# Error, skipping
# Processing : sao felix do xingu
# Processing : nsanje
# Processing : havoysund
# Processing : okato
# Processing : kutum
# Processing : teya
# Processing : vieste
# Processing : sambava
# Processing : coahuayana
# Processing : moron
# Processing : petatlan
# Processing : turukhansk
# Processing : college
# Processing : neka
# Processing : spornoye
# Processing : cumaribo
# Error, skipping
# Processing : jalu
# Processing : rairangpur
# Processing : kanye
# Processing : vreed en hoop
# Error, skipping
# Processing : turayf
# Processing : geraldton
# Processing : pisco
# Processing : xining
# Processing : dombarovskiy
# Processing : kingaroy
# Processing : pedasi
# Processing : camacupa
# Processing : bargal
# Error, skipping
# Processing : bakchar
# Processing : saint-joseph
# Processing : oliva
# Processing : wahran
# Error, skipping
# Processing : khao yoi
# Processing : tautira
# Processing : conceicao do araguaia
# Processing : marcona
# Error, skipping
# Processing : halalo
# Error, skipping
# Processing : takaka
# Processing : quiindy
# Processing : lompoc
# Processing : nguiu
# Error, skipping
# Processing : la asuncion
# Processing : bolungarvik
# Error, skipping
# Processing : svetlyy
# Error, skipping
# Processing : iqaluit
# Processing : sibu
# Processing : pachino
# Processing : tamale
# Processing : tiksi
# Processing : acarau
# Error, skipping
# Processing : kiunga
# Processing : porto torres
# Processing : port hardy
# Processing : faya
# Processing : lapeer
# Processing : garm
# Error, skipping
# Processing : grindavik
# Processing : tocopilla
# Processing : rab
# Error, skipping
# Processing : touros
# Processing : polyarnyy
# Processing : tingo maria
# Processing : sanming
# Processing : kuvshinovo
# Processing : monrovia
# Processing : byron bay
# Processing : okha
# Processing : hobyo
# Processing : krasnoborsk
# Processing : nikolayevsk-na-amure
# Processing : ozgon
# Error, skipping
# Processing : sovetskiy
# Processing : sampit
# Processing : fort saint john
# Error, skipping
# Processing : manokwari
# Processing : prince rupert
# Processing : rio branco
# Processing : greencastle
# Processing : rapid city
# Processing : taber
# Processing : changchun
# Processing : manaus
# Processing : oyama
# Processing : ewa beach
# Processing : jiujiang
# Processing : sisimiut
# Processing : torres
# Processing : luderitz
# Processing : redlands
# Processing : karachev
# Processing : matara
# Processing : skibbereen
# Processing : agadir
# Processing : laguna
# Processing : deer lake
# Processing : khodz
# Processing : el tarra
# Processing : katiola
# Processing : coihaique
# Processing : la ronge
# Processing : meulaboh
# Processing : rio grande
# Processing : zaragoza

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City" : cit,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Latitude" : lat,
    "Longitude" : lon,
    "Max Temp" : max_temp,
    "Wind Speed" : wind_speed
}

weather_df = pd.DataFrame(weather_dict)
weather_df.to_csv("")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
